# %% [markdown]
# ### Global Training Normalizaiton

# %%
import os
import json
import numpy as np
from glob import glob

def normalize_train_set_from_split(input_root, output_root, split_json, stats_path='norm_stats.json', revised_split_path='data_split_revised.json'):
    os.makedirs(output_root, exist_ok=True)

    # --- load split json ---
    with open(split_json, 'r', encoding='utf-8') as f:
        split_data = json.load(f)

    # --- validate files ---
    revised_split = {}
    for split_name, files in split_data.items():
        valid_files = []
        for rel_path in files:
            full_path = os.path.join(input_root, rel_path)
            if os.path.exists(full_path):
                valid_files.append(rel_path)
            else:
                print(f'⚠️ File not found and skipped: {rel_path}')
        revised_split[split_name] = valid_files

    # --- save revised split ---
    with open(revised_split_path, 'w', encoding='utf-8') as f:
        json.dump(revised_split, f, indent=2, ensure_ascii=False)
    print(f'Saved revised split to "{revised_split_path}"')

    train_files = revised_split.get('train', [])

    def to_np(key, people):
        arr = people.get(key, [])
        arr = np.array(arr)
        if arr.size == 0:
            return np.zeros((0, 3))
        return arr.reshape(-1, 3)

    pose_all = []
    hand_all = []

    # --- 통계 계산: 존재하는 train 파일만 ---
    print(f'Collecting stats from {len(train_files)} valid training files')
    for rel_path in train_files:
        file_path = os.path.join(input_root, rel_path)
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
        people = data['landmarks']
        pose = to_np('pose_keypoints_3d', people)
        hand_l = to_np('hand_left_keypoints_3d', people)
        hand_r = to_np('hand_right_keypoints_3d', people)

        if pose.size > 0:
            pose_all.append(pose)
        if hand_l.size > 0:
            hand_all.append(hand_l)
        if hand_r.size > 0:
            hand_all.append(hand_r)

    # --- 통계 계산 ---
    pose_all_np = np.concatenate(pose_all, axis=0) if pose_all else np.zeros((0, 3))
    hand_all_np = np.concatenate(hand_all, axis=0) if hand_all else np.zeros((0, 3))

    pose_mean = pose_all_np.mean(axis=0)
    pose_std = pose_all_np.std(axis=0) + 1e-6
    hand_min = hand_all_np.min(axis=0)
    hand_max = hand_all_np.max(axis=0)

    stats = {
        'pose_mean': pose_mean.tolist(),
        'pose_std': pose_std.tolist(),
        'hand_min': hand_min.tolist(),
        'hand_max': hand_max.tolist()
    }

    with open(stats_path, 'w', encoding='utf-8') as f:
        json.dump(stats, f, indent=2)
    print(f'Saved normalization stats to "{stats_path}"')

    # --- 정규화 함수 ---
    def normalize_pose(pose):
        return (pose - pose_mean) / pose_std if pose.size > 0 else pose

    def normalize_hand(hand):
        return (hand - hand_min) / (hand_max - hand_min + 1e-6) if hand.size > 0 else hand

    def to_list(x):
        return x.flatten().tolist() if x.size > 0 else []

    # --- 전체 파일 정규화 ---
    print('Applying normalization to all .json files...')
    all_files = glob(os.path.join(input_root, '**', '*.json'), recursive=True)
    for file_path in all_files:
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
        people = data['landmarks']

        pose = to_np('pose_keypoints_3d', people)
        hand_l = to_np('hand_left_keypoints_3d', people)
        hand_r = to_np('hand_right_keypoints_3d', people)

        pose_n = normalize_pose(pose)
        hand_l_n = normalize_hand(hand_l)
        hand_r_n = normalize_hand(hand_r)

        people['pose_keypoints_3d'] = to_list(pose_n)
        people['hand_left_keypoints_3d'] = to_list(hand_l_n)
        people['hand_right_keypoints_3d'] = to_list(hand_r_n)

        rel_path = os.path.relpath(file_path, input_root)
        output_file_path = os.path.join(output_root, rel_path)
        os.makedirs(os.path.dirname(output_file_path), exist_ok=True)

        with open(output_file_path, 'w', encoding='utf-8') as f:
            json.dump(data, f, ensure_ascii=False, indent=2)

    print('Finished applying normalization to all files.')

# %%
normalize_train_set_from_split(
    input_root = 'C:/Users/이예지학부휴학통계학과/Downloads/raw',
    output_root = 'C:/Users/이예지학부휴학통계학과/Downloads/normalized',
    split_json='C:/Users/이예지학부휴학통계학과/Downloads/conference/.venv/NIA-1-69 재난안전정보 수어영상 데이터_AI 모델소스/data/data_split.json',
    stats_path='C:/Users/이예지학부휴학통계학과/Downloads/conference/.venv/NIA-1-69 재난안전정보 수어영상 데이터_AI 모델소스/data/norm_stats.json',
    revised_split_path='C:/Users/이예지학부휴학통계학과/Downloads/conference/.venv/NIA-1-69 재난안전정보 수어영상 데이터_AI 모델소스/data/data_split_revised.json'
)
# Out:
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001747_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001747_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000879_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004347_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002390_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004113_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003237_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003131_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004292_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002305_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001098_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002888_2_TW30.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002131_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002387_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002700_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000546_1_TW114.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004444_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000248_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003407_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000676_1_TW114.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002884_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004468_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000424_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002835_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000269_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001965_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004161_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004213_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001512_1_TW104.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003199_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000498_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000431_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000273_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000571_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004009_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004106_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004315_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002884_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001823_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002976_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002534_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003260_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004347_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002980_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001214_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000273_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000602_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000086_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002728_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001949_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004149_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002305_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001391_1_TW104.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000946_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001005_2_TW04.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003436_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001509_1_TW104.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002986_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003619_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001007_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003407_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001427_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002836_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001912_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001436_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004434_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003457_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004273_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001209_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001005_1_TW04.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004055_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000801_2_TW114.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001822_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000613_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003085_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002706_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001960_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002561_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000479_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001103_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001603_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001667_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000460_1_TW114.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002700_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004124_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000993_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001965_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001192_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003442_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000315_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002884_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000301_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000673_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003456_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003824_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000613_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000676_2_TW114.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001631_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000801_1_TW114.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003365_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000325_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003847_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001233_2_TW04.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000183_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003591_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003977_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000133_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000901_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001148_1_TW04.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001770_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001960_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004084_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001436_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000815_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001331_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003494_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003904_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003433_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002534_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001257_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002164_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004368_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002408_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000479_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003147_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002249_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001124_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004368_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000341_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000505_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002939_2_TW30.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000313_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001412_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001098_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000088_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000292_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001454_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002129_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003525_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001376_1_TW104.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001687_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001159_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001654_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003006_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003028_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002973_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004231_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001937_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004084_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004213_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001652_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000273_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002769_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002734_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000400_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003402_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002818_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003619_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001007_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003364_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000315_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002197_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002685_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003561_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002532_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002706_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000613_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003816_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001823_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002965_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000183_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003019_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001139_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000879_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001233_1_TW04.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002234_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002728_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001349_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001427_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003488_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002857_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001687_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003816_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001603_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003803_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000879_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000734_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000970_2_TW04.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000212_2_TW114.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003457_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004006_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004200_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002733_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001092_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001912_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003438_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001412_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003650_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002976_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000512_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001264_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002955_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000315_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001667_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000531_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002408_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001799_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003137_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002713_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002796_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001454_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003868_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003649_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001137_2_TW04.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002979_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001799_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003847_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001802_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001032_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000189_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003006_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004074_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003575_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000963_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001007_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002197_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000526_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000734_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000425_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000621_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003175_2_TW30.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001054_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004021_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001349_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000382_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001621_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002374_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002604_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003053_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000538_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004347_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001061_2_TW04.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003365_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003585_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003278_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001802_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001858_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000646_1_TW114.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001537_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003777_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003457_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003047_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000772_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001179_1_TW04.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001023_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002980_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004256_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002168_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001799_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000183_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001714_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004434_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002161_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000785_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000776_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000481_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002771_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000963_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004468_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000581_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000479_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003510_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002685_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001770_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000133_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002374_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003916_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002973_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004434_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004292_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003649_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001714_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002161_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000292_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003822_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002090_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000152_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001607_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002604_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003006_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000963_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003763_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001129_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001802_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004130_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004213_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003777_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000423_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000802_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001098_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001537_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003858_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002733_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003364_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004467_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003844_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001687_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000292_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000802_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002980_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002168_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002864_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000901_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003407_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000152_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001349_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004444_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000459_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000487_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003649_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001607_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001248_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003726_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003775_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003364_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002771_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000301_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000481_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000110_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002833_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001591_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001733_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000093_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001667_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002131_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000505_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001523_1_TW104.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000812_2_TW114.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003156_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002161_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000009_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002734_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002908_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001331_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002387_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003262_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001831_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000646_2_TW114.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003162_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001186_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002129_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002908_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001654_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000133_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002501_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000505_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002532_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000896_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001733_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004002_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001386_1_TW104.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003575_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002986_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000510_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003175_1_TW30.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001747_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000644_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002131_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003626_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003847_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004130_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002164_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002501_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001092_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000460_2_TW114.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002384_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000946_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002384_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000368_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002833_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003619_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002908_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002888_1_TW30.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004165_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000326_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001096_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002973_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000012_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004467_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002833_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002384_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003020_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000152_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003985_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001770_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003869_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000546_2_TW114.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001467_1_TW104.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000578_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003584_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001374_1_TW104.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001242_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003767_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002976_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001120_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003816_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003688_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002986_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003418_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001220_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001831_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003554_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001148_2_TW04.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004129_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001061_1_TW04.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000621_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002875_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000481_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002939_1_TW30.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001303_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000054_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002501_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001858_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001395_1_TW104.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000878_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004342_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003189_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001823_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000802_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002773_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000812_1_TW114.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003308_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002532_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001176_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003425_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001652_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004467_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000059_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001440_1_TW104.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001960_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001434_1_TW104.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003740_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002234_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002713_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002713_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000649_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004468_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002773_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001631_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003156_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003088_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002408_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000970_1_TW04.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001389_1_TW104.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000790_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001573_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003365_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001937_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003027_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003412_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000413_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001175_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000248_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000946_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000980_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001346_1_TW104.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002728_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004215_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001621_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001350_1_TW104.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001459_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001131_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002168_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003156_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000113_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004130_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000248_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001179_2_TW04.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001652_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004368_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000309_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004292_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002561_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000621_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003348_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001137_1_TW04.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000301_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002129_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003964_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002734_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001454_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000901_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000176_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001427_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001487_1_TW104.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002700_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001436_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002249_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003777_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000924_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003339_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003015_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001041_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003112_1_CROWD1075776.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001331_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002090_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003575_1_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001092_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002706_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001631_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000734_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004333_1_CROWD1075744.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002390_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002604_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001012_1_TW87.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004444_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE004084_2_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001303_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001573_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE000241_1_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001591_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001949_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001822_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE002090_3_KU02.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE001459_2_TW03.json
# ⚠️ File not found and skipped: NIA_SL_G2_FIRE003415_1_CROWD1075776.json
# Saved revised split to "C:/Users/이예지학부휴학통계학과/Downloads/conference/.venv/NIA-1-69 재난안전정보 수어영상 데이터_AI 모델소스/data/data_split_revised.json"
# Collecting stats from 3367 valid training files

# %% [markdown]
# ### Global Validation Normalization

# %%
import os
import json
import numpy as np
from glob import glob

def normalize_validation_set(input_root, output_root, keywords, stats_path='norm_stats.json'):
    os.makedirs(output_root, exist_ok=True)

    # --- 통계 불러오기 ---
    with open(stats_path, 'r', encoding='utf-8') as f:
        stats = json.load(f)

    pose_mean = np.array(stats['pose_mean'])
    pose_std = np.array(stats['pose_std']) + 1e-6
    hand_min = np.array(stats['hand_min'])
    hand_max = np.array(stats['hand_max'])
    hand_range = hand_max - hand_min + 1e-6

    def to_np(key, people):
        arr = people.get(key, [])
        arr = np.array(arr)
        if arr.size == 0:
            return np.zeros((0, 3))
        return arr.reshape(-1, 3)

    def normalize_pose(pose):
        if pose.size == 0:
            return pose
        return (pose - pose_mean) / pose_std

    def normalize_hand(hand):
        if hand.size == 0:
            return hand
        return (hand - hand_min) / hand_range

    def to_list(x):
        return x.flatten().tolist() if x.size > 0 else []

    for keyword in keywords:
        print(f'Normalizing validation keyword: {keyword}')
        files = glob(os.path.join(input_root, '**', f'*{keyword}*.json'), recursive=True)
        for file_path in files:
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)
            people = data['landmarks']

            pose = to_np('pose_keypoints_3d', people)
            hand_l = to_np('hand_left_keypoints_3d', people)
            hand_r = to_np('hand_right_keypoints_3d', people)

            pose_n = normalize_pose(pose)
            hand_l_n = normalize_hand(hand_l)
            hand_r_n = normalize_hand(hand_r)

            people['pose_keypoints_3d'] = to_list(pose_n)
            people['hand_left_keypoints_3d'] = to_list(hand_l_n)
            people['hand_right_keypoints_3d'] = to_list(hand_r_n)

            rel_path = os.path.relpath(file_path, input_root)
            output_file_path = os.path.join(output_root, rel_path)
            os.makedirs(os.path.dirname(output_file_path), exist_ok=True)

            with open(output_file_path, 'w', encoding='utf-8') as f:
                json.dump(data, f, ensure_ascii=False, indent=2)

        print(f'Finished normalizing validation keyword: {keyword}')

# %%
normalize_validation_set(
    input_root='C:/Users/이예지학부휴학통계학과/Downloads/tact_morpheme_val/1_1',
    output_root='C:/Users/이예지학부휴학통계학과/Downloads/normalized',
    keywords=['TW03', 'TW87', 'TW104'],
    stats_path='norm_stats.json'
)

# %%
normalize_validation_set(
    input_root='C:/Users/이예지학부휴학통계학과/Downloads/tact_morpheme_val/1_2',
    output_root='C:/Users/이예지학부휴학통계학과/Downloads/normalized',
    keywords=['TW03', 'TW114', 'TW04', 'TW30'],
    stats_path='norm_stats.json'
)

# %%
normalize_validation_set(
    input_root='C:/Users/이예지학부휴학통계학과/Downloads/tact_morpheme_val/1_3',
    output_root='C:/Users/이예지학부휴학통계학과/Downloads/normalized',
    keywords=['KU02'],
    stats_path='norm_stats.json'
)

# %%
normalize_validation_set(
    input_root='C:/Users/이예지학부휴학통계학과/Downloads/untact_morpheme_val/1_1',
    output_root='C:/Users/이예지학부휴학통계학과/Downloads/normalized',
    keywords=['CROWD04', 'CROWD1067644', 'CROWD1075', 'CROWD128', 'CROWD87', 'CROWD112'],
    stats_path='norm_stats.json'
)

# %%
import json
import numpy as np

def normalize_keypoints_from_json(input_json_path, output_json_path, mode='all'):
    
    with open(input_json_path, 'r') as f:
        data = json.load(f)
    people = data['landmarks']

    def to_np(key):
        arr = people.get(key, [])
        arr = np.array(arr)
        if arr.size == 0:
            return np.zeros((0, 3))
        return arr.reshape(-1, 3)

    pose = to_np('pose_keypoints_3d')
    hand_l = to_np('hand_left_keypoints_3d')
    hand_r = to_np('hand_right_keypoints_3d')
    face = to_np('face_keypoints_3d')

    # 정규화 함수 정의
    def normalize_all_parts(pose, hand_l, hand_r, face):
        all_pts = [x for x in [pose, hand_l, hand_r, face] if x.size > 0]
        if not all_pts:
            return pose, hand_l, hand_r, face
        all_pts = np.concatenate(all_pts, axis=0)
        min_xy = all_pts[:, :3].min(axis=0)
        max_xy = all_pts[:, :3].max(axis=0)
        scale = (max_xy - min_xy) + 1e-6
        def apply_norm(x):
            if x.size == 0:
                return x
            x_norm = x.copy()
            x_norm[:, :3] = (x[:, :3] - min_xy) / scale
            return x_norm
        return (
            apply_norm(pose),
            apply_norm(hand_l),
            apply_norm(hand_r),
            apply_norm(face)
        )

    def normalize_by_part(pose, hand_l, hand_r, face):
        def normalize(part, anchor_idx):
            if part.size == 0 or anchor_idx >= len(part):
                return part
            anchor = part[anchor_idx, :3]
            rel = part[:, :3] - anchor  # anchor 기준 상대 좌표
            scale = np.linalg.norm(rel, axis=1).max() + 1e-6
            part_norm = part.copy()
            part_norm[:, :3] = rel / scale
            return part_norm
        # 하체 제외 (pose index: 9~14 제거)
        upper_pose_indices = [i for i in range(len(pose)) if i not in [9,10,11,12,13,14]]
        pose_upper = pose[upper_pose_indices]
        pose_norm = normalize(pose_upper, anchor_idx=1)       # 목을 anchor로 (index 1: Neck)
        left_norm = normalize(hand_l, anchor_idx=0)           # 왼손: 손목 기준
        right_norm = normalize(hand_r, anchor_idx=0)          # 오른손: 손목 기준
        face_norm = normalize(face, anchor_idx=30)            # 얼굴: 코 기준
        return pose_norm, left_norm, right_norm, face_norm

    # 정규화 적용
    if mode == 'all':
        pose_n, hand_l_n, hand_r_n, face_n = normalize_all_parts(pose, hand_l, hand_r, face)
    elif mode == 'part':
        pose_n, hand_l_n, hand_r_n, face_n = normalize_by_part(pose, hand_l, hand_r, face)
    else:
        raise ValueError("mode은 'all' 또는 'part'만 가능합니다.")

    # 다시 json 형태로 변환
    def to_list(x):
        return x.flatten().tolist() if x.size > 0 else []
    people['pose_keypoints_3d'] = to_list(pose_n)
    people['hand_left_keypoints_3d'] = to_list(hand_l_n)
    people['hand_right_keypoints_3d'] = to_list(hand_r_n)
    people['face_keypoints_3d'] = to_list(face_n)

    with open(output_json_path, 'w') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)
        
input_json_path = 'C:/Users/dpwl1/Downloads/FIRE/1_1/NIA_SL_G2_FIRE001529_1_TW104.json'
output_json_path = 'C:/Users/dpwl1/Downloads/FIRE_normalized/1_1/NIA_SL_G2_FIRE001529_1_TW104.json'

normalize_keypoints_from_json(input_json_path, output_json_path, mode='part')

# %% [markdown]
# ### Training dataset Normalization

# %%
import os
import json
import numpy as np
from glob import glob

def normalize_group_by_keyword(input_root, output_root, keywords, mode='all'):
    os.makedirs(output_root, exist_ok=True)

    def to_np(key, people):
        arr = people.get(key, [])
        arr = np.array(arr)
        if arr.size == 0:
            return np.zeros((0, 3))
        return arr.reshape(-1, 3)

    def normalize_all_parts(pose, hand_l, hand_r, face, min_xy, scale):
        def apply_norm(x):
            if x.size == 0:
                return x
            x_norm = x.copy()
            x_norm[:, :3] = (x[:, :3] - min_xy) / scale
            return x_norm
        return (
            apply_norm(pose),
            apply_norm(hand_l),
            apply_norm(hand_r),
            apply_norm(face)
        )

    def normalize_by_part(pose, hand_l, hand_r, face):
        def normalize(part, anchor_idx):
            if part.size == 0 or anchor_idx >= len(part):
                return part
            anchor = part[anchor_idx, :3]
            rel = part[:, :3] - anchor
            scale = np.linalg.norm(rel, axis=1).max() + 1e-6
            part_norm = part.copy()
            part_norm[:, :3] = rel / scale
            return part_norm

        upper_pose_indices = [i for i in range(len(pose)) if i not in [9,10,11,12,13,14]]
        pose_upper = pose[upper_pose_indices]
        pose_norm = normalize(pose_upper, anchor_idx=1)     # 목
        hand_l_norm = normalize(hand_l, anchor_idx=0)       # 왼손목
        hand_r_norm = normalize(hand_r, anchor_idx=0)       # 오른손목
        face_norm = normalize(face, anchor_idx=30)          # 코
        return pose_norm, hand_l_norm, hand_r_norm, face_norm

    def to_list(x):
        return x.flatten().tolist() if x.size > 0 else []

    for keyword in keywords:
        print(f'Processing keyword: {keyword}')
        files = glob(os.path.join(input_root, '**', f'*{keyword}*.json'), recursive=True)
        if not files:
            print(f'No files found for keyword: {keyword}')
            continue

        # mode='all'인 경우 전체 정규화 기준 계산
        if mode == 'all':
            all_keypoints = []
            for file_path in files:
                with open(file_path, 'r') as f:
                    data = json.load(f)
                people = data['landmarks']
                pose = to_np('pose_keypoints_3d', people)
                hand_l = to_np('hand_left_keypoints_3d', people)
                hand_r = to_np('hand_right_keypoints_3d', people)
                face = to_np('face_keypoints_3d', people)

                parts = [x for x in [pose, hand_l, hand_r, face] if x.size > 0]
                if parts:
                    all_keypoints.append(np.concatenate(parts, axis=0))
            if not all_keypoints:
                continue
            all_points = np.concatenate(all_keypoints, axis=0)
            min_xy = all_points[:, :3].min(axis=0)
            max_xy = all_points[:, :3].max(axis=0)
            scale = (max_xy - min_xy) + 1e-6

        # 각 파일에 정규화 적용 및 저장
        for file_path in files:
            with open(file_path, 'r') as f:
                data = json.load(f)
            people = data['landmarks']
            pose = to_np('pose_keypoints_3d', people)
            hand_l = to_np('hand_left_keypoints_3d', people)
            hand_r = to_np('hand_right_keypoints_3d', people)
            face = to_np('face_keypoints_3d', people)

            if mode == 'all':
                pose_n, hand_l_n, hand_r_n, face_n = normalize_all_parts(pose, hand_l, hand_r, face, min_xy, scale)
            elif mode == 'part':
                pose_n, hand_l_n, hand_r_n, face_n = normalize_by_part(pose, hand_l, hand_r, face)
            else:
                raise ValueError("mode는 'all' 또는 'part' 중 하나여야 합니다.")

            people['pose_keypoints_3d'] = to_list(pose_n)
            people['hand_left_keypoints_3d'] = to_list(hand_l_n)
            people['hand_right_keypoints_3d'] = to_list(hand_r_n)
            people['face_keypoints_3d'] = to_list(face_n)

            rel_path = os.path.relpath(file_path, input_root)
            output_file_path = os.path.join(output_root, rel_path)
            os.makedirs(os.path.dirname(output_file_path), exist_ok=True)

            with open(output_file_path, 'w') as f:
                json.dump(data, f, ensure_ascii=False, indent=2)

        print(f'Normalized {len(files)} files for keyword \"{keyword}\" in mode \"{mode}\".')

# %%
# 사용 예시
input_root = 'C:/Users/dpwl1/Downloads/tact_morpheme/1_1'
output_root = 'C:/Users/dpwl1/Downloads/normalized'
keywords = ['TW03', 'TW87', 'TW104']  # 원하는 키워드 목록

normalize_group_by_keyword(input_root, output_root, keywords, mode='part')
# Out:
# Processing keyword: TW03
# Normalized 354 files for keyword "TW03" in mode "part".
# Processing keyword: TW87
# Normalized 270 files for keyword "TW87" in mode "part".
# Processing keyword: TW104
# Normalized 93 files for keyword "TW104" in mode "part".

# %%
# 사용 예시
input_root = 'C:/Users/dpwl1/Downloads/tact_morpheme/1_2'
output_root = 'C:/Users/dpwl1/Downloads/normalized'
keywords = ['TW03', 'TW114', 'TW04', 'TW30']  # 원하는 키워드 목록

normalize_group_by_keyword(input_root, output_root, keywords, mode='part')
# Out:
# Processing keyword: TW03
# Normalized 438 files for keyword "TW03" in mode "part".
# Processing keyword: TW114
# Normalized 242 files for keyword "TW114" in mode "part".
# Processing keyword: TW04
# Normalized 78 files for keyword "TW04" in mode "part".
# Processing keyword: TW30
# Normalized 158 files for keyword "TW30" in mode "part".

# %%
# 사용 예시
input_root = 'C:/Users/dpwl1/Downloads/tact_morpheme/1_3'
output_root = 'C:/Users/dpwl1/Downloads/normalized'
keywords = ['KU02']  # 원하는 키워드 목록

normalize_group_by_keyword(input_root, output_root, keywords, mode='part')
# Out:
# Processing keyword: KU02
# Normalized 1962 files for keyword "KU02" in mode "part".

# %%
# 사용 예시
input_root = 'C:/Users/dpwl1/Downloads/untact_morpheme/1_1'
output_root = 'C:/Users/dpwl1/Downloads/normalized'
keywords = ['CROWD04', 'CROWD1067644', 'CROWD1075', 'CROWD128', 'CROWD87', 'CROWD112']  # 원하는 키워드 목록

normalize_group_by_keyword(input_root, output_root, keywords, mode='part')
# Out:
# Processing keyword: CROWD04
# Normalized 643 files for keyword "CROWD04" in mode "part".
# Processing keyword: CROWD1067644
# Normalized 943 files for keyword "CROWD1067644" in mode "part".
# Processing keyword: CROWD1075
# Normalized 724 files for keyword "CROWD1075" in mode "part".
# Processing keyword: CROWD128
# Normalized 29 files for keyword "CROWD128" in mode "part".
# Processing keyword: CROWD87
# Normalized 21 files for keyword "CROWD87" in mode "part".
# Processing keyword: CROWD112
# Normalized 281 files for keyword "CROWD112" in mode "part".

# %% [markdown]
# ### Validation dataset Normalization

# %%
import os
import json
import numpy as np
from glob import glob

def to_np(key, people):
    arr = people.get(key, [])
    arr = np.array(arr)
    if arr.size == 0:
        return np.zeros((0, 3))
    return arr.reshape(-1, 3)

def to_list(x):
    return x.flatten().tolist() if x.size > 0 else []

def normalize_all_parts(pose, hand_l, hand_r, face, min_xy, scale):
    def apply_norm(x):
        if x.size == 0:
            return x
        x_norm = x.copy()
        x_norm[:, :3] = (x[:, :3] - min_xy) / scale
        return x_norm
    return (
        apply_norm(pose),
        apply_norm(hand_l),
        apply_norm(hand_r),
        apply_norm(face)
    )

def normalize_by_part(pose, hand_l, hand_r, face):
    def normalize(part, anchor_idx):
        if part.size == 0 or anchor_idx >= len(part):
            return part
        anchor = part[anchor_idx, :3]
        rel = part[:, :3] - anchor
        scale = np.linalg.norm(rel, axis=1).max() + 1e-6
        part_norm = part.copy()
        part_norm[:, :3] = rel / scale
        return part_norm

    upper_pose_indices = [i for i in range(len(pose)) if i not in [9,10,11,12,13,14]]
    pose_upper = pose[upper_pose_indices]
    pose_norm = normalize(pose_upper, anchor_idx=1)
    hand_l_norm = normalize(hand_l, anchor_idx=0)
    hand_r_norm = normalize(hand_r, anchor_idx=0)
    face_norm = normalize(face, anchor_idx=30)
    return pose_norm, hand_l_norm, hand_r_norm, face_norm

def compute_training_stats(input_root, keywords):
    """각 keyword별 (min, scale) 계산"""
    stats = {}

    for keyword in keywords:
        files = glob(os.path.join(input_root, '**', f'*{keyword}*.json'), recursive=True)
        all_keypoints = []
        for file_path in files:
            with open(file_path, 'r') as f:
                data = json.load(f)
            people = data['landmarks']
            pose = to_np('pose_keypoints_3d', people)
            hand_l = to_np('hand_left_keypoints_3d', people)
            hand_r = to_np('hand_right_keypoints_3d', people)
            face = to_np('face_keypoints_3d', people)

            parts = [x for x in [pose, hand_l, hand_r, face] if x.size > 0]
            if parts:
                all_keypoints.append(np.concatenate(parts, axis=0))

        if all_keypoints:
            all_points = np.concatenate(all_keypoints, axis=0)
            min_xy = all_points[:, :3].min(axis=0)
            max_xy = all_points[:, :3].max(axis=0)
            scale = (max_xy - min_xy) + 1e-6
            stats[keyword] = (min_xy, scale)
        else:
            print(f"[Warning] No training keypoints found for keyword: {keyword}")

    return stats

def normalize_validation_data(input_root, output_root, keywords, stats, mode='all'):
    os.makedirs(output_root, exist_ok=True)

    files = glob(os.path.join(input_root, '**', '*.json'), recursive=True)

    for file_path in files:
        filename = os.path.basename(file_path)
        matched_keyword = next((k for k in keywords if k in filename), None)

        if matched_keyword is None:
            print(f"[Skip] No matching keyword for file: {filename}")
            continue

        min_xy, scale = stats.get(matched_keyword, (None, None))
        if min_xy is None or scale is None:
            print(f"[Warning] No normalization stats for keyword: {matched_keyword}")
            continue

        with open(file_path, 'r') as f:
            data = json.load(f)
        people = data['landmarks']
        pose = to_np('pose_keypoints_3d', people)
        hand_l = to_np('hand_left_keypoints_3d', people)
        hand_r = to_np('hand_right_keypoints_3d', people)
        face = to_np('face_keypoints_3d', people)

        if mode == 'all':
            pose_n, hand_l_n, hand_r_n, face_n = normalize_all_parts(pose, hand_l, hand_r, face, min_xy, scale)
        elif mode == 'part':
            pose_n, hand_l_n, hand_r_n, face_n = normalize_by_part(pose, hand_l, hand_r, face)
        else:
            raise ValueError("mode는 'all' 또는 'part' 중 하나여야 합니다.")

        people['pose_keypoints_3d'] = to_list(pose_n)
        people['hand_left_keypoints_3d'] = to_list(hand_l_n)
        people['hand_right_keypoints_3d'] = to_list(hand_r_n)
        people['face_keypoints_3d'] = to_list(face_n)

        rel_path = os.path.relpath(file_path, input_root)
        output_file_path = os.path.join(output_root, rel_path)
        os.makedirs(os.path.dirname(output_file_path), exist_ok=True)

        with open(output_file_path, 'w') as f:
            json.dump(data, f, ensure_ascii=False, indent=2)

        print(f'[OK] Normalized: {rel_path}')

# %%
train_root = 'C:/Users/dpwl1/Downloads/tact_morpheme/1_1'
val_root = 'C:/Users/dpwl1/Downloads/tact_morpheme_val/1_1'
val_out = 'C:/Users/dpwl1/Downloads/normalized'
keywords = ['TW03', 'TW87', 'TW104']  # 원하는 키워드 지정

# Step 1. training data 기준 계산
stats = compute_training_stats(train_root, keywords)

# Step 2. validation data 정규화 적용
normalize_validation_data(val_root, val_out, keywords, stats, mode='part')
# Out:
# [OK] Normalized: NIA_SL_G2_FIRE000009_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000012_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000054_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000059_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000086_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000088_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000093_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000110_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000113_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000176_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000189_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000241_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000269_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000309_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000313_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000325_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000326_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000341_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000368_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000382_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000400_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000413_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000423_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000424_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000425_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000431_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000459_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000487_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000498_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000510_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000512_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000526_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000531_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000538_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000571_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000578_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000581_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000602_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000644_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000649_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000673_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE000772_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE000776_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE000785_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE000790_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE000815_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE000878_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE000896_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE000924_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE000980_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE000993_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE001012_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE001023_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE001032_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE001041_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE001054_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE001096_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE001103_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE001120_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE001124_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE001129_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE001131_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE001139_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE001159_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE001175_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE001176_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE001186_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE001192_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE001209_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE001214_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE001220_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE001242_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE001248_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE001257_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE001264_1_TW87.json
# [OK] Normalized: NIA_SL_G2_FIRE001346_1_TW104.json
# [OK] Normalized: NIA_SL_G2_FIRE001350_1_TW104.json
# [OK] Normalized: NIA_SL_G2_FIRE001374_1_TW104.json
# [OK] Normalized: NIA_SL_G2_FIRE001376_1_TW104.json
# [OK] Normalized: NIA_SL_G2_FIRE001386_1_TW104.json
# [OK] Normalized: NIA_SL_G2_FIRE001389_1_TW104.json
# [OK] Normalized: NIA_SL_G2_FIRE001391_1_TW104.json
# [OK] Normalized: NIA_SL_G2_FIRE001395_1_TW104.json
# [OK] Normalized: NIA_SL_G2_FIRE001434_1_TW104.json
# [OK] Normalized: NIA_SL_G2_FIRE001440_1_TW104.json
# [OK] Normalized: NIA_SL_G2_FIRE001467_1_TW104.json
# [OK] Normalized: NIA_SL_G2_FIRE001487_1_TW104.json
# [OK] Normalized: NIA_SL_G2_FIRE001509_1_TW104.json
# [OK] Normalized: NIA_SL_G2_FIRE001512_1_TW104.json
# [OK] Normalized: NIA_SL_G2_FIRE001523_1_TW104.json

# %%
train_root = 'C:/Users/dpwl1/Downloads/tact_morpheme/1_2'
val_root = 'C:/Users/dpwl1/Downloads/tact_morpheme_val/1_2'
val_out = 'C:/Users/dpwl1/Downloads/normalized'
keywords = ['TW03', 'TW114', 'TW04', 'TW30']  # 원하는 키워드 지정

# Step 1. training data 기준 계산
stats = compute_training_stats(train_root, keywords)

# Step 2. validation data 정규화 적용
normalize_validation_data(val_root, val_out, keywords, stats, mode='part')
# Out:
# [OK] Normalized: NIA_SL_G2_FIRE000043_1_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000043_2_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000121_1_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000121_2_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000212_1_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000212_2_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000219_1_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000219_2_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000221_1_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000221_2_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000247_1_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000247_2_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000346_1_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000346_2_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000396_1_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000396_2_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000460_1_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000460_2_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000546_1_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000546_2_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000646_1_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000646_2_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000676_1_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000676_2_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000801_1_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000801_2_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000812_1_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000812_2_TW114.json
# [OK] Normalized: NIA_SL_G2_FIRE000970_1_TW04.json
# [OK] Normalized: NIA_SL_G2_FIRE000970_2_TW04.json
# [OK] Normalized: NIA_SL_G2_FIRE001005_1_TW04.json
# [OK] Normalized: NIA_SL_G2_FIRE001005_2_TW04.json
# [OK] Normalized: NIA_SL_G2_FIRE001061_1_TW04.json
# [OK] Normalized: NIA_SL_G2_FIRE001061_2_TW04.json
# [OK] Normalized: NIA_SL_G2_FIRE001137_1_TW04.json
# [OK] Normalized: NIA_SL_G2_FIRE001137_2_TW04.json
# [OK] Normalized: NIA_SL_G2_FIRE001148_1_TW04.json
# [OK] Normalized: NIA_SL_G2_FIRE001148_2_TW04.json
# [OK] Normalized: NIA_SL_G2_FIRE001179_1_TW04.json
# [OK] Normalized: NIA_SL_G2_FIRE001179_2_TW04.json
# [OK] Normalized: NIA_SL_G2_FIRE001233_1_TW04.json
# [OK] Normalized: NIA_SL_G2_FIRE001233_2_TW04.json
# [OK] Normalized: NIA_SL_G2_FIRE001303_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001303_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001412_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001412_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001459_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001459_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001537_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001537_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001573_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001573_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001591_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001591_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001603_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001603_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001607_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001607_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001621_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001621_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001654_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001654_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001714_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001714_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001733_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001733_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001822_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001822_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001831_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001831_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001858_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001858_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001912_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001912_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001937_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001937_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001949_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001949_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001965_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE001965_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002164_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002164_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002197_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002197_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002234_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002234_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002249_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002249_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002305_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002305_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002374_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002374_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002387_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002387_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002390_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002390_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002534_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002534_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002561_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002561_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002685_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002685_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002733_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002733_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002771_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002771_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002773_1_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002773_2_TW03.json
# [OK] Normalized: NIA_SL_G2_FIRE002888_1_TW30.json
# [OK] Normalized: NIA_SL_G2_FIRE002888_2_TW30.json
# [OK] Normalized: NIA_SL_G2_FIRE002939_1_TW30.json
# [OK] Normalized: NIA_SL_G2_FIRE002939_2_TW30.json
# [OK] Normalized: NIA_SL_G2_FIRE003175_1_TW30.json
# [OK] Normalized: NIA_SL_G2_FIRE003175_2_TW30.json

# %%
train_root = 'C:/Users/dpwl1/Downloads/tact_morpheme/1_3'
val_root = 'C:/Users/dpwl1/Downloads/tact_morpheme_val/1_3'
val_out = 'C:/Users/dpwl1/Downloads/normalized'
keywords = ['KU02']  # 원하는 키워드 지정

# Step 1. training data 기준 계산
stats = compute_training_stats(train_root, keywords)

# Step 2. validation data 정규화 적용
normalize_validation_data(val_root, val_out, keywords, stats, mode='part')
# Out:
# [OK] Normalized: NIA_SL_G2_FIRE000133_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000133_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000133_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000152_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000152_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000152_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000183_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000183_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000183_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000248_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000248_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000248_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000273_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000273_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000273_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000292_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000292_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000292_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000301_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000301_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000301_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000315_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000315_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000315_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000479_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000479_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000479_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000481_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000481_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000481_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000505_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000505_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000505_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000613_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000613_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000613_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000621_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000621_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000621_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000734_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000734_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000734_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000802_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000802_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000802_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000879_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000879_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000879_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000901_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000901_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000901_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000946_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000946_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000946_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000963_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000963_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE000963_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001007_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001007_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001007_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001092_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001092_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001092_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001098_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001098_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001098_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001331_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001331_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001331_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001349_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001349_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001349_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001427_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001427_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001427_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001436_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001436_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001436_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001454_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001454_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001454_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001631_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001631_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001631_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001652_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001652_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001652_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001667_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001667_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001667_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001687_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001687_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001687_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001747_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001747_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001747_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001770_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001770_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001770_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001799_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001799_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001799_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001802_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001802_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001802_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001823_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001823_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001823_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001960_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001960_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE001960_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002090_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002090_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002090_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002129_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002129_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002129_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002131_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002131_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002131_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002161_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002161_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002161_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002168_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002168_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002168_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002384_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002384_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002384_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002408_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002408_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002408_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002501_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002501_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002501_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002532_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002532_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002532_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002604_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002604_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002604_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002700_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002700_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002700_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002706_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002706_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002706_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002713_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002713_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002713_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002728_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002728_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002728_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002734_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002734_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002734_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002833_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002833_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002833_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002884_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002884_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002884_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002908_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002908_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002908_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002973_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002973_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002973_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002976_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002976_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002976_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002980_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002980_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002980_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002986_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002986_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE002986_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003006_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003006_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003006_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003156_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003156_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003156_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003364_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003364_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003364_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003365_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003365_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003365_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003407_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003407_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003407_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003457_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003457_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003457_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003575_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003575_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003575_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003619_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003619_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003619_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003649_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003649_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003649_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003777_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003777_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003777_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003816_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003816_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003816_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003847_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003847_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE003847_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004084_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004084_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004084_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004130_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004130_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004130_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004213_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004213_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004213_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004273_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004292_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004292_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004292_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004347_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004347_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004347_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004368_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004368_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004368_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004434_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004434_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004434_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004444_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004444_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004444_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004467_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004467_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004467_3_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004468_1_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004468_2_KU02.json
# [OK] Normalized: NIA_SL_G2_FIRE004468_3_KU02.json

# %%
train_root = 'C:/Users/dpwl1/Downloads/untact_morpheme/1_1'
val_root = 'C:/Users/dpwl1/Downloads/untact_morpheme_val/1_1'
val_out = 'C:/Users/dpwl1/Downloads/normalized'
keywords = ['CROWD04', 'CROWD1067644', 'CROWD1075', 'CROWD128', 'CROWD87', 'CROWD112']  # 원하는 키워드 지정

# Step 1. training data 기준 계산
stats = compute_training_stats(train_root, keywords)

# Step 2. validation data 정규화 적용
normalize_validation_data(val_root, val_out, keywords, stats, mode='part')
# Out:
# [Warning] No training keypoints found for keyword: CROWD04
# [Warning] No training keypoints found for keyword: CROWD1067644
# [Warning] No training keypoints found for keyword: CROWD1075
# [Warning] No training keypoints found for keyword: CROWD128
# [Warning] No training keypoints found for keyword: CROWD87
# [Warning] No training keypoints found for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD87
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD87
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD87
# [Warning] No normalization stats for keyword: CROWD87
# [Warning] No normalization stats for keyword: CROWD87
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD128
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD128
# [Warning] No normalization stats for keyword: CROWD128
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD1075
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD1067644
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD04
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD112
# [Warning] No normalization stats for keyword: CROWD04

# %%
import os
import json
import numpy as np
from glob import glob

def normalize_group_by_keyword_with_split(input_root, output_root, split_json_path, keywords, mode='all'):
    os.makedirs(output_root, exist_ok=True)

    # Load data split information
    with open(split_json_path, 'r', encoding='utf-8') as f:
        data_split = json.load(f)

    # Flatten all paths and group by split
    split_paths = {
        split: [os.path.join(input_root, path) for path in paths]
        for split, paths in data_split.items()
    }

    def to_np(key, people):
        arr = people.get(key, [])
        arr = np.array(arr)
        if arr.size == 0:
            return np.zeros((0, 3))
        return arr.reshape(-1, 3)

    def normalize_all_parts(pose, hand_l, hand_r, face, min_xy, scale):
        def apply_norm(x):
            if x.size == 0:
                return x
            x_norm = x.copy()
            x_norm[:, :3] = (x[:, :3] - min_xy) / scale
            return x_norm
        return (
            apply_norm(pose),
            apply_norm(hand_l),
            apply_norm(hand_r),
            apply_norm(face)
        )

    def normalize_by_part(pose, hand_l, hand_r, face):
        def normalize(part, anchor_idx):
            if part.size == 0 or anchor_idx >= len(part):
                return part
            anchor = part[anchor_idx, :3]
            rel = part[:, :3] - anchor
            scale = np.linalg.norm(rel, axis=1).max() + 1e-6
            part_norm = part.copy()
            part_norm[:, :3] = rel / scale
            return part_norm

        upper_pose_indices = [i for i in range(len(pose)) if i not in [9,10,11,12,13,14]]
        pose_upper = pose[upper_pose_indices]
        pose_norm = normalize(pose_upper, anchor_idx=1)     # 목
        hand_l_norm = normalize(hand_l, anchor_idx=0)       # 왼손목
        hand_r_norm = normalize(hand_r, anchor_idx=0)       # 오른손목
        face_norm = normalize(face, anchor_idx=30)          # 코
        return pose_norm, hand_l_norm, hand_r_norm, face_norm

    def to_list(x):
        return x.flatten().tolist() if x.size > 0 else []

    # Process each keyword
    for keyword in keywords:
        print(f'Processing keyword: {keyword}')

        # Step 1: Compute normalization parameters from TRAIN data only
        train_files = [f for f in split_paths['train'] if keyword in os.path.basename(f)]
        if not train_files:
            print(f'No train files found for keyword: {keyword}')
            continue

        if mode == 'all':
            all_keypoints = []
            for file_path in train_files:
                with open(file_path, 'r', encoding='utf-8') as f:
                    data = json.load(f)
                people = data['landmarks']
                pose = to_np('pose_keypoints_3d', people)
                hand_l = to_np('hand_left_keypoints_3d', people)
                hand_r = to_np('hand_right_keypoints_3d', people)
                face = to_np('face_keypoints_3d', people)

                parts = [x for x in [pose, hand_l, hand_r, face] if x.size > 0]
                if parts:
                    all_keypoints.append(np.concatenate(parts, axis=0))
            if not all_keypoints:
                print(f'No valid keypoints in train files for keyword: {keyword}')
                continue
            all_points = np.concatenate(all_keypoints, axis=0)
            min_xy = all_points[:, :3].min(axis=0)
            max_xy = all_points[:, :3].max(axis=0)
            scale = (max_xy - min_xy) + 1e-6

        # Step 2: Apply normalization to all (train + valid + test) files
        all_files = sum(split_paths.values(), [])  # flatten all splits
        target_files = [f for f in all_files if keyword in os.path.basename(f)]
        print(f'Applying normalization to {len(target_files)} files.')

        for file_path in target_files:
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)
            people = data['landmarks']
            pose = to_np('pose_keypoints_3d', people)
            hand_l = to_np('hand_left_keypoints_3d', people)
            hand_r = to_np('hand_right_keypoints_3d', people)
            face = to_np('face_keypoints_3d', people)

            if mode == 'all':
                pose_n, hand_l_n, hand_r_n, face_n = normalize_all_parts(pose, hand_l, hand_r, face, min_xy, scale)
            elif mode == 'part':
                pose_n, hand_l_n, hand_r_n, face_n = normalize_by_part(pose, hand_l, hand_r, face)
            else:
                raise ValueError("mode는 'all' 또는 'part' 중 하나여야 합니다.")

            people['pose_keypoints_3d'] = to_list(pose_n)
            people['hand_left_keypoints_3d'] = to_list(hand_l_n)
            people['hand_right_keypoints_3d'] = to_list(hand_r_n)
            people['face_keypoints_3d'] = to_list(face_n)

            rel_path = os.path.relpath(file_path, input_root)
            output_file_path = os.path.join(output_root, rel_path)
            os.makedirs(os.path.dirname(output_file_path), exist_ok=True)

            with open(output_file_path, 'w', encoding='utf-8') as f:
                json.dump(data, f, ensure_ascii=False, indent=2)

        print(f'Finished keyword: {keyword}\n')

# 사용 예시
input_root = 'C:/Users/dpwl1/Downloads/labeled'
output_root = 'C:/Users/dpwl1/Downloads/normalized'
split_json_path = 'C:/Users/dpwl1/Desktop/대학교/KUBIG/2025-1 Conference/AI 모델 소스코드/NIA-1-69 재난안전정보 수어영상 데이터_AI 모델소스/data/data_split.json'
keywords = ['TW03', 'TW87', 'TW104', 'TW114', 'TW04', 'TW30', 'KU02', 'CROWD04', 'CROWD1067644', 'CROWD1075', 'CROWD128', 'CROWD87', 'CROWD112']

normalize_group_by_keyword_with_split(input_root, output_root, split_json_path, keywords, mode='part')  # 또는 'all'
# Out:
# Processing keyword: TW03
# Applying normalization to 996 files.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 135
#     132 split_json_path = 'C:/Users/dpwl1/Desktop/대학교/KUBIG/2025-1 Conference/AI 모델 소스코드/NIA-1-69 재난안전정보 수어영상 데이터_AI 모델소스/data/data_split.json'
#     133 keywords = ['TW03', 'TW87', 'TW104', 'TW114', 'TW04', 'TW30', 'KU02', 'CROWD04', 'CROWD1067644', 'CROWD1075', 'CROWD128', 'CROWD87', 'CROWD112']
# --> 135 normalize_group_by_keyword_with_split(input_root, output_root, split_json_path, keywords, mode='part')
#
# Cell In[21], line 100, in normalize_group_by_keyword_with_split(input_root, output_root, split_json_path, keywords, mode)
#      97 print(f'Applying normalization to {len(target_files)} files.')
#      99 for file_path in target_files:
# --> 100     with open(file_path, 'r', encoding='utf-8') as f:
#     101         data = json.load(f)
#     102     people = data['landmarks']
#
# File c:\Users\dpwl1\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/dpwl1/Downloads/labeled\\NIA_SL_G2_FIRE000412_1_TW03.json'

# %%
import os
import json
import numpy as np
from glob import glob

def normalize_group_by_keyword_with_split(input_root, output_root, split_json_path, keywords, mode='all'):
    os.makedirs(output_root, exist_ok=True)

    # Load data split information
    with open(split_json_path, 'r', encoding='utf-8') as f:
        data_split = json.load(f)

    missing_files = []
    rev_data_split = {k: v.copy() for k, v in data_split.items()}  # 사본을 만들어 수정에 사용

    # Flatten all paths and group by split, checking file existence
    split_paths = {}
    for split, paths in data_split.items():
        full_paths = []
        for path in paths:
            full_path = os.path.join(input_root, path)
            if os.path.exists(full_path):
                full_paths.append(full_path)
            else:
                missing_files.append(full_path)
                if path in rev_data_split[split]:  # 제거
                    rev_data_split[split].remove(path)
        split_paths[split] = full_paths

    def to_np(key, people):
        arr = people.get(key, [])
        arr = np.array(arr)
        if arr.size == 0:
            return np.zeros((0, 3))
        return arr.reshape(-1, 3)

    def normalize_all_parts(pose, hand_l, hand_r, face, min_xy, scale):
        def apply_norm(x):
            if x.size == 0:
                return x
            x_norm = x.copy()
            x_norm[:, :3] = (x[:, :3] - min_xy) / scale
            return x_norm
        return (
            apply_norm(pose),
            apply_norm(hand_l),
            apply_norm(hand_r),
            apply_norm(face)
        )

    def normalize_by_part(pose, hand_l, hand_r, face):
        def normalize(part, anchor_idx):
            if part.size == 0 or anchor_idx >= len(part):
                return part
            anchor = part[anchor_idx, :3]
            rel = part[:, :3] - anchor
            scale = np.linalg.norm(rel, axis=1).max() + 1e-6
            part_norm = part.copy()
            part_norm[:, :3] = rel / scale
            return part_norm

        upper_pose_indices = [i for i in range(len(pose)) if i not in [9,10,11,12,13,14]]
        pose_upper = pose[upper_pose_indices]
        pose_norm = normalize(pose_upper, anchor_idx=1)     # 목
        hand_l_norm = normalize(hand_l, anchor_idx=0)       # 왼손목
        hand_r_norm = normalize(hand_r, anchor_idx=0)       # 오른손목
        face_norm = normalize(face, anchor_idx=30)          # 코
        return pose_norm, hand_l_norm, hand_r_norm, face_norm

    def to_list(x):
        return x.flatten().tolist() if x.size > 0 else []

    for keyword in keywords:
        print(f'Processing keyword: {keyword}')

        # Step 1: Compute normalization parameters from TRAIN data only
        train_files = [f for f in split_paths['train'] if keyword in os.path.basename(f)]
        if not train_files:
            print(f'No train files found for keyword: {keyword}')
            continue

        if mode == 'all':
            all_keypoints = []
            for file_path in train_files:
                with open(file_path, 'r', encoding='utf-8') as f:
                    data = json.load(f)
                people = data['landmarks']
                pose = to_np('pose_keypoints_3d', people)
                hand_l = to_np('hand_left_keypoints_3d', people)
                hand_r = to_np('hand_right_keypoints_3d', people)
                face = to_np('face_keypoints_3d', people)

                parts = [x for x in [pose, hand_l, hand_r, face] if x.size > 0]
                if parts:
                    all_keypoints.append(np.concatenate(parts, axis=0))
            if not all_keypoints:
                print(f'No valid keypoints in train files for keyword: {keyword}')
                continue
            all_points = np.concatenate(all_keypoints, axis=0)
            min_xy = all_points[:, :3].min(axis=0)
            max_xy = all_points[:, :3].max(axis=0)
            scale = (max_xy - min_xy) + 1e-6

        # Step 2: Apply normalization to all (train + valid + test) files
        all_files = sum(split_paths.values(), [])  # flatten all splits
        target_files = [f for f in all_files if keyword in os.path.basename(f)]
        print(f'Applying normalization to {len(target_files)} files.')

        for file_path in target_files:
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)
            people = data['landmarks']
            pose = to_np('pose_keypoints_3d', people)
            hand_l = to_np('hand_left_keypoints_3d', people)
            hand_r = to_np('hand_right_keypoints_3d', people)
            face = to_np('face_keypoints_3d', people)

            if mode == 'all':
                pose_n, hand_l_n, hand_r_n, face_n = normalize_all_parts(pose, hand_l, hand_r, face, min_xy, scale)
            elif mode == 'part':
                pose_n, hand_l_n, hand_r_n, face_n = normalize_by_part(pose, hand_l, hand_r, face)
            else:
                raise ValueError("mode는 'all' 또는 'part' 중 하나여야 합니다.")

            people['pose_keypoints_3d'] = to_list(pose_n)
            people['hand_left_keypoints_3d'] = to_list(hand_l_n)
            people['hand_right_keypoints_3d'] = to_list(hand_r_n)
            people['face_keypoints_3d'] = to_list(face_n)

            rel_path = os.path.relpath(file_path, input_root)
            output_file_path = os.path.join(output_root, rel_path)
            os.makedirs(os.path.dirname(output_file_path), exist_ok=True)

            with open(output_file_path, 'w', encoding='utf-8') as f:
                json.dump(data, f, ensure_ascii=False, indent=2)

        print(f'Finished keyword: {keyword}\n')

    # Save revised data split without missing files
    rev_json_path = split_json_path.replace('.json', '_rev.json')
    with open(rev_json_path, 'w', encoding='utf-8') as f:
        json.dump(rev_data_split, f, ensure_ascii=False, indent=2)
    print(f"\n수정된 split 파일 저장 완료: {rev_json_path}")

    # 마지막에 누락된 파일 경로 출력
    if missing_files:
        print("\n누락된 파일들 (split JSON에는 있지만 실제로 존재하지 않음):")
        for path in missing_files:
            print(f'- {path}')
    else:
        print("\n모든 파일이 존재합니다.")


# 사용 예시
input_root = 'C:/Users/dpwl1/Downloads/labeled'
output_root = 'C:/Users/dpwl1/Downloads/normalized'
split_json_path = 'C:/Users/dpwl1/Desktop/대학교/KUBIG/2025-1 Conference/AI 모델 소스코드/NIA-1-69 재난안전정보 수어영상 데이터_AI 모델소스/data/data_split.json'
keywords = ['TW03', 'TW87', 'TW104', 'TW114', 'TW04', 'TW30', 'KU02', 'CROWD04', 'CROWD1067644', 'CROWD1075', 'CROWD128', 'CROWD87', 'CROWD112']

normalize_group_by_keyword_with_split(input_root, output_root, split_json_path, keywords, mode='part')
# Out:
# Processing keyword: TW03
# Applying normalization to 896 files.
# Finished keyword: TW03
#
# Processing keyword: TW87
# Applying normalization to 304 files.
# Finished keyword: TW87
#
# Processing keyword: TW104
# Applying normalization to 108 files.
# Finished keyword: TW104
#
# Processing keyword: TW114
# Applying normalization to 134 files.
# Finished keyword: TW114
#
# Processing keyword: TW04
# Applying normalization to 92 files.
# Finished keyword: TW04
#
# Processing keyword: TW30
# Applying normalization to 164 files.
# Finished keyword: TW30
#
# Processing keyword: KU02
# Applying normalization to 2206 files.
# Finished keyword: KU02
#
# Processing keyword: CROWD04
# No train files found for keyword: CROWD04
# Processing keyword: CROWD1067644
# No train files found for keyword: CROWD1067644
# Processing keyword: CROWD1075
# Applying normalization to 817 files.
# Finished keyword: CROWD1075
#
# Processing keyword: CROWD128
# No train files found for keyword: CROWD128
# Processing keyword: CROWD87
# No train files found for keyword: CROWD87
# Processing keyword: CROWD112
# No train files found for keyword: CROWD112
#
# 수정된 split 파일 저장 완료: C:/Users/dpwl1/Desktop/대학교/KUBIG/2025-1 Conference/AI 모델 소스코드/NIA-1-69 재난안전정보 수어영상 데이터_AI 모델소스/data/data_split_rev.json
#
# 누락된 파일들 (split JSON에는 있지만 실제로 존재하지 않음):
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000987_1_TW87.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002928_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002761_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002340_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002507_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002248_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001546_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001697_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002405_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000861_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002185_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002314_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002625_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003813_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002653_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002092_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002381_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001314_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001780_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000707_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000863_1_TW87.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001914_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000045_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002068_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000208_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004423_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001358_1_TW104.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002179_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001703_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002473_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000861_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001855_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002102_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002477_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001582_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002095_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001073_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004102_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001524_1_TW104.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000520_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002439_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001813_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002296_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001351_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000711_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004178_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001938_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001750_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001870_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004103_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002492_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003353_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002151_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001710_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004406_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003315_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001843_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004017_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001723_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002378_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001735_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002638_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001283_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001744_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002654_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001740_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001564_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001321_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000902_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002233_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002682_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001590_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001963_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002338_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002193_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001681_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001416_1_TW104.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004432_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001657_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001558_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003251_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002286_2_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001865_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001926_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002108_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003461_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002652_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004172_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001583_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002172_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002723_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000588_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003227_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001688_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003005_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002597_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001291_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004012_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001796_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001682_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001895_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001892_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000364_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001426_1_TW104.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000656_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002677_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002136_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003854_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001100_1_TW87.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003124_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001803_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002297_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002311_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001116_1_TW04.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004423_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000184_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002103_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002332_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001977_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001614_1_CROWD1073935.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004110_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001661_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001700_2_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001584_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000731_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000685_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003176_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001660_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001229_1_TW87.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001565_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000163_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002758_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001315_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001966_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002631_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001280_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002683_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004102_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001835_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002668_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002356_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002265_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002021_2_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004017_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002128_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001001_1_TW87.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001010_1_TW04.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002420_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002618_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003276_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000724_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003678_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002563_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000163_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001324_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001060_2_TW04.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001779_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001781_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002264_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001800_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000364_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001272_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002333_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003998_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001707_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002405_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003250_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002566_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000265_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003662_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000758_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001749_2_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002694_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001908_2_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003095_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001962_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003651_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002060_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003610_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002404_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001852_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001953_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002361_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001060_1_TW04.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000832_1_TW87.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002564_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000164_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001856_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000412_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002230_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001692_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003939_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001553_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003974_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004072_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002573_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000761_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003464_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001336_1_TW104.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000728_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001677_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002880_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002504_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002406_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000034_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002255_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002273_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004017_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002705_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000726_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002762_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000766_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001694_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000760_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001287_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003939_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002165_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000699_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002491_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001961_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002019_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002573_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002547_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000361_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002021_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002856_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002257_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002231_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002156_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001932_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001869_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001668_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002216_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002423_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002576_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003695_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002065_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002581_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002533_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002018_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003814_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001626_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001825_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003707_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002306_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002379_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002595_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001778_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001876_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001508_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002516_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002623_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003926_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002031_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004137_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001911_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001197_1_TW87.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002442_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001576_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002007_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002745_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003209_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002481_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002622_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001741_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001894_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002054_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002921_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002321_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003417_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003478_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000255_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002082_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002359_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001720_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002398_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001460_1_TW104.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001394_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003464_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002953_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002334_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002235_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002402_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001299_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003196_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003547_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003547_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001946_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001551_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002152_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001933_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001961_2_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001864_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002620_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001277_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001554_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003786_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001941_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002088_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002601_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001905_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001780_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002048_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002367_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002011_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002302_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002464_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000754_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002636_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000001_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002555_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002808_2_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001881_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002275_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001884_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002748_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001193_1_TW04.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002075_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002444_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000155_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001727_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003600_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002639_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002523_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001550_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004228_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004053_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002437_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001539_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002376_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003813_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002441_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002137_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001602_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002078_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002275_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002322_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002310_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000687_2_TW114.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001570_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000763_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000184_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001634_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001806_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001394_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000609_2_TW114.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002427_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002358_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002719_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001443_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001624_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002562_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002623_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004204_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002410_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002250_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000971_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002671_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001883_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002614_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002050_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004102_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002729_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002461_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003547_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001650_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000184_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002403_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004172_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003980_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002061_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001899_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002003_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002629_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001978_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000596_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002726_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002382_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000704_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001094_1_TW87.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004432_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000733_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001659_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000555_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002447_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002186_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000029_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002100_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001612_1_CROWD1073935.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001296_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001600_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001629_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000006_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000497_2_TW114.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002560_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001904_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000703_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002117_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002432_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002703_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004220_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002449_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004204_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003917_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001500_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002198_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000191_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002741_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001635_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001073_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002689_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002094_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002143_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001302_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001975_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001991_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002567_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002533_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000696_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002221_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002266_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002938_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001136_1_TW87.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002665_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002105_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002424_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001246_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000164_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000162_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001586_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000902_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001320_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000188_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002201_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002150_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001973_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002014_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003254_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001898_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002405_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000752_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002377_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001544_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000407_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001633_2_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002057_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001727_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000702_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002035_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003598_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002928_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002596_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002200_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001764_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001954_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002414_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004279_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001734_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001737_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001278_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003473_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001037_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001655_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002502_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003124_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002585_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002535_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002508_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000103_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002536_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002299_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002740_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002395_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001666_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002715_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002559_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001889_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001828_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001969_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001030_1_TW87.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002928_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002170_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000739_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001605_1_CROWD1073935.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001855_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001829_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002412_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002432_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002175_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001989_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001980_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000971_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000260_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002188_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000520_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001316_2_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001931_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002458_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001766_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002209_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002127_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003294_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004012_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002407_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001948_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001647_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002079_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001754_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001567_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001777_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001535_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001896_2_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002217_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003209_2_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000736_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000137_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000155_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001904_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001839_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002470_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002517_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002240_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001828_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001313_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003851_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000755_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001545_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002162_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002901_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001981_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002210_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002524_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002211_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002217_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001828_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003786_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003320_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000155_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001998_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004164_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002662_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002371_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002337_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001768_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002806_2_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000497_1_TW114.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001780_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001566_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002551_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002396_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001833_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002627_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002510_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001578_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001246_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004146_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001943_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002215_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002511_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002027_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003286_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002528_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001957_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002681_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000447_1_TW114.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001756_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000598_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002000_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001329_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000439_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000764_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000235_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001543_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002247_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000372_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002097_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002364_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004162_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002425_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002446_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002350_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001818_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000827_1_TW87.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002493_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001817_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002318_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001987_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004337_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001834_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000164_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002475_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000902_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002672_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002017_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003320_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004069_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002393_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002592_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000725_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002699_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000735_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000029_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001345_1_TW104.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001563_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003998_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004290_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000705_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001327_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004087_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002113_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002648_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001997_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001628_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002819_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004010_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001665_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002212_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001016_1_TW87.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003974_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001787_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000570_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001413_1_TW104.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001270_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001906_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003354_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001620_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002300_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003331_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003596_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002583_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001394_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003813_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002544_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002372_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001501_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003950_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002725_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000757_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004182_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001317_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002121_1_CROWD1075744.json
# ...
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001882_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002196_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000507_1_TW114.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001930_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002747_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001761_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000943_1_TW87.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001351_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000544_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001752_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004340_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002394_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002515_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002471_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001536_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003939_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001309_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002202_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002676_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000718_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001166_1_TW87.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002342_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002073_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001508_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002133_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000744_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004012_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002520_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002294_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004432_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002661_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002056_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000691_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000603_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003200_2_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002144_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001513_1_TW104.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002630_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002005_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002589_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001801_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001809_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001830_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002324_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003704_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001743_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002077_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000520_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000933_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000207_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000712_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002603_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002217_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002649_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000010_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002208_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002503_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001056_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002526_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004162_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002476_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002498_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002246_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001670_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002602_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001749_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002312_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002529_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001814_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003353_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002628_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001653_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000968_1_TW87.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002944_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000343_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001622_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001860_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001713_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001691_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000740_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000507_2_TW114.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002006_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003662_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003428_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002901_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002453_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003320_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001636_2_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003464_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003970_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000384_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002307_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001915_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001737_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001738_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003929_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001985_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001786_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002468_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002633_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002545_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001701_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002590_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001919_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002199_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003286_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001585_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002432_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001673_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001286_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000746_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002483_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002251_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001917_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002811_2_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002058_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002429_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002028_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001751_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002067_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001581_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001934_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002451_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000105_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002366_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003247_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002537_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001669_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002859_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002181_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002411_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004243_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001308_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003428_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001837_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000724_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000933_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002663_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003090_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002239_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000727_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002463_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002684_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002178_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002026_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001810_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001772_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001498_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002591_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002272_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002421_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002436_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002660_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001904_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003281_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001994_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002283_2_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001458_1_TW104.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001623_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000609_1_TW114.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003286_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002670_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003864_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000971_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004269_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001907_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002099_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001699_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002375_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002531_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002732_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001037_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002543_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001501_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001658_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001916_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002001_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001783_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000714_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002873_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001300_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001656_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002658_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000957_2_TW114.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002195_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001704_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002623_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002124_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000724_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003227_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002051_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE004236_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001939_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001992_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE003353_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002811_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002183_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001953_1_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001228_3_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000447_2_TW114.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002326_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001754_2_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002806_1_TW03.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002391_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001428_1_TW104.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002348_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002083_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002140_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002479_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001982_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002455_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002580_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE000720_1_TW30.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002550_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001936_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001228_2_KU02.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002612_1_CROWD1075744.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE002650_1_CROWD1075776.json
# - C:/Users/dpwl1/Downloads/labeled\NIA_SL_G2_FIRE001727_1_KU02.json
